# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd

# %%
df = pd.read_csv('en.openfoodfacts.org.products.tsv', sep='\t')
# Out:
# /var/folders/bg/vsg5dtcj4z7fjns1l6fq09140000gn/T/ipykernel_49930/90184969.py:1: DtypeWarning: Columns (0: code, 1: created_t, 2: last_modified_t, 3: manufacturing_places, 4: manufacturing_places_tags, 5: emb_codes, 6: emb_codes_tags, 7: first_packaging_code_geo, 8: cities, 9: cities_tags, 10: allergens_en, 11: traces, 12: traces_tags, 13: traces_en, 14: ingredients_from_palm_oil_tags) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('en.openfoodfacts.org.products.tsv', sep='\t')

# %% [markdown]
# ### Step 4. See the first 5 entries

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?
